# %% [markdown]
# # Exploratory Data Analysis

# %%
# Import requirements
import warnings

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# Set defaults
# %matplotlib inline
warnings.filterwarnings('ignore')
plt.style.use('fivethirtyeight')
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)
pd.options.display.float_format = "{:,.2f}".format
plt.rcParams['figure.figsize'] = (12, 10)
# %config InlineBackend.figure_formats = ['retina', 'svg']

# %%
# Load data
movies = pd.read_csv("archive/Movie_Movies.csv", low_memory=False)
genres = pd.read_csv("archive/Movie_Genres.csv", low_memory=False)
ratings = pd.read_csv("archive/Movie_AdditionalRating.csv", low_memory=False)

# %%
# Overview
movies.head()
# Out:
#   Awards    Country  DVD             Director   Language  \
# 0    NaN        USA  NaN        Rose Cummings    English
# 1    NaN        USA  NaN          James Byrne        NaN
# 2    NaN        USA  NaN  Dimitri Buchowetzki        NaN
# 3    NaN        USA  NaN        Julia Hechler    English
# 4    NaN  Sri Lanka  NaN      Udara Siriruwan  Sinhalese
#
#                                                 Plot Poster Production Rated  \
# 0  Rachel constantly hears her baby cry from the ...    NaN        NaN   NaN
# 1  The struggle against unfortunate circumstances...    NaN        NaN   NaN
# 2                                                NaN    NaN        NaN   NaN
# 3  A Gift introduces Samuel Green, Washington Sta...    NaN        NaN   NaN
# 4                                                NaN    NaN        NaN   NaN
#
#       Released Runtime              Title   Type Website  Year     imdbID  \
# 0  26 Apr 2012  20 min      Baby's Breath  movie     NaN  2012  tt2268369
# 1          NaN   9 min       Winter Trees  movie     NaN  2008  tt1560760
# 2  27 Mar 1926  50 min  The Crown of Lies  movie     NaN  1926  tt0016750
# 3  27 May 2013   2 min             A Gift  movie     NaN  2013  tt3405286
# 4  20 Mar 2014  23 min            Journey  movie     NaN  2014  tt3816698
#
#    imdbRating imdbVotes
# 0         NaN       NaN
# 1         NaN       NaN
# 2         NaN       NaN
# 3         NaN       NaN
# 4         NaN       NaN

# %%
# General info
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178687 entries, 0 to 178686
# Data columns (total 18 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Awards      20340 non-null   object
#  1   Country     165998 non-null  object
#  2   DVD         15949 non-null   object
#  3   Director    151353 non-null  object
#  4   Language    153196 non-null  object
#  5   Plot        97476 non-null   object
#  6   Poster      48414 non-null   object
#  7   Production  16446 non-null   object
#  8   Rated       23906 non-null   object
#  9   Released    116974 non-null  object
#  10  Runtime     119497 non-null  object
#  11  Title       178686 non-null  object
#  12  Type        178686 non-null  object
#  13  Website     6747 non-null    object
#  14  Year        178686 non-null  object
#  15  imdbID      178686 non-null  object
#  16  imdbRating  62073 non-null   float64
#  17  imdbVotes   62029 non-null   object
# dtypes: float64(1), object(17)
# memory usage: 24.5+ MB

# %%
# Description on some columns
movies.describe(include='all')
# Out:
#                Awards Country          DVD    Director Language  \
# count           20340  165998        15949      151353   153196
# unique           1946    3799         2586       92410     2519
# top     1 nomination.     USA  29 Mar 2005  Jim Powers  English
# freq             4134   93426           82         151   117809
# mean              NaN     NaN          NaN         NaN      NaN
# std               NaN     NaN          NaN         NaN      NaN
# min               NaN     NaN          NaN         NaN      NaN
# 25%               NaN     NaN          NaN         NaN      NaN
# 50%               NaN     NaN          NaN         NaN      NaN
# 75%               NaN     NaN          NaN         NaN      NaN
# max               NaN     NaN          NaN         NaN      NaN
#
#                                                      Plot  \
# count                                               97476
# unique                                              97166
# top     Scenes of the coronation ceremonies of King Ed...
# freq                                                   12
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                    Poster          Production  \
# count                                               48414               16446
# unique                                              48209                4815
# top     http://ia.media-imdb.com/images/M/MV5BMTI4NDcz...  Paramount Pictures
# freq                                                    8                 414
# mean                                                  NaN                 NaN
# std                                                   NaN                 NaN
# min                                                   NaN                 NaN
# 25%                                                   NaN                 NaN
# 50%                                                   NaN                 NaN
# 75%                                                   NaN                 NaN
# max                                                   NaN                 NaN
#
#         Rated     Released Runtime   Title    Type  \
# count   23906       116974  119497  178686  178686
# unique     80        25146     535  158218       2
# top         R  01 May 2015  90 min   Alone   movie
# freq     5115          173    4391      84  178665
# mean      NaN          NaN     NaN     NaN     NaN
# std       NaN          NaN     NaN     NaN     NaN
# min       NaN          NaN     NaN     NaN     NaN
# 25%       NaN          NaN     NaN     NaN     NaN
# 50%       NaN          NaN     NaN     NaN     NaN
# 75%       NaN          NaN     NaN     NaN     NaN
# max       NaN          NaN     NaN     NaN     NaN
#
#                             Website    Year     imdbID  imdbRating imdbVotes
# count                          6747  178686     178686   62,073.00     62029
# unique                         6240     265     178686         NaN      8538
# top     http://www.phase4films.com/    2015  tt2299475         NaN         5
# freq                             26    9543          1         NaN      3143
# mean                            NaN     NaN        NaN        6.42       NaN
# std                             NaN     NaN        NaN        1.36       NaN
# min                             NaN     NaN        NaN        1.00       NaN
# 25%                             NaN     NaN        NaN        5.60       NaN
# 50%                             NaN     NaN        NaN        6.50       NaN
# 75%                             NaN     NaN        NaN        7.30       NaN
# max                             NaN     NaN        NaN       10.00       NaN

# %%
# Drop unnecessary columns
movies = movies.drop(['Awards','DVD','Plot','Poster','Website'],axis=1)

# %%
# Checking for null values
movies.isnull().sum()
# Out:
# Country        12689
# Director       27334
# Language       25491
# Production    162241
# Rated         154781
# Released       61713
# Runtime        59190
# Title              1
# Type               1
# Year               1
# imdbID             1
# imdbRating    116614
# imdbVotes     116658
# dtype: int64

# %%
# Checking for duplicated values
movies[movies.duplicated(['imdbID'],keep=False)]
# Out:
# Empty DataFrame
# Columns: [Country, Director, Language, Production, Rated, Released, Runtime, Title, Type, Year, imdbID, imdbRating, imdbVotes]
# Index: []

# %%
# Cleaning data
movies.dropna(subset=['imdbID'],inplace=True)

# %%
# Get info again
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 178686 entries, 0 to 178686
# Data columns (total 13 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Country     165998 non-null  object
#  1   Director    151353 non-null  object
#  2   Language    153196 non-null  object
#  3   Production  16446 non-null   object
#  4   Rated       23906 non-null   object
#  5   Released    116974 non-null  object
#  6   Runtime     119497 non-null  object
#  7   Title       178686 non-null  object
#  8   Type        178686 non-null  object
#  9   Year        178686 non-null  object
#  10  imdbID      178686 non-null  object
#  11  imdbRating  62073 non-null   float64
#  12  imdbVotes   62029 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 19.1+ MB

# %%
# Change some columns to categories
movies.Language = movies.Language.astype('category')
movies.Rated = movies.Rated.astype('category')
movies.Type = movies.Type.astype('category')

# %%
# Convert Year to integer
movies['Year'] = pd.to_numeric(movies['Year'], errors='coerce', downcast='integer')
movies['Year'] = movies['Year'].fillna(0)
movies['Year'] = movies['Year'].astype('int32')

# %%
# Convert Runtime to integer
movies['Runtime'] = movies['Runtime'].astype(str).str.replace(' min','')
movies['Runtime'] = pd.to_numeric(movies['Runtime'], errors='coerce', downcast='integer')
movies['Runtime'] = movies['Runtime'].fillna(0)
movies['Runtime'] = movies['Runtime'].astype('int32')

# %%
# Convert imdbVotes to integer
movies['imdbVotes'] = movies['imdbVotes'].astype(str).str.replace(',','')
movies['imdbVotes'] = pd.to_numeric(movies['imdbVotes'],errors='coerce')
movies['imdbVotes'] = movies['imdbVotes'].fillna(0)
movies['imdbVotes'] = movies['imdbVotes'].astype('int32')

# %%
# Convert Released to datetime
movies['Released'] = pd.to_datetime(movies['Released'])

# %%
# Get info again
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 178686 entries, 0 to 178686
# Data columns (total 13 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Country     165998 non-null  object
#  1   Director    151353 non-null  object
#  2   Language    153196 non-null  category
#  3   Production  16446 non-null   object
#  4   Rated       23906 non-null   category
#  5   Released    116974 non-null  datetime64[ns]
#  6   Runtime     178686 non-null  int32
#  7   Title       178686 non-null  object
#  8   Type        178686 non-null  category
#  9   Year        178686 non-null  int32
#  10  imdbID      178686 non-null  object
#  11  imdbRating  62073 non-null   float64
#  12  imdbVotes   178686 non-null  int32
# dtypes: category(3), datetime64[ns](1), float64(1), int32(3), object(5)
# memory usage: 13.7+ MB

# %%
# Description on some columns again
movies.describe(include='all')
# Out:
#        Country    Director Language          Production  Rated  \
# count   165998      151353   153196               16446  23906
# unique    3799       92410     2519                4815     80
# top        USA  Jim Powers  English  Paramount Pictures      R
# freq     93426         151   117809                 414   5115
# first      NaN         NaN      NaN                 NaN    NaN
# last       NaN         NaN      NaN                 NaN    NaN
# mean       NaN         NaN      NaN                 NaN    NaN
# std        NaN         NaN      NaN                 NaN    NaN
# min        NaN         NaN      NaN                 NaN    NaN
# 25%        NaN         NaN      NaN                 NaN    NaN
# 50%        NaN         NaN      NaN                 NaN    NaN
# 75%        NaN         NaN      NaN                 NaN    NaN
# max        NaN         NaN      NaN                 NaN    NaN
#
#                    Released    Runtime   Title    Type       Year     imdbID  \
# count                116974 178,686.00  178686  178686 178,686.00     178686
# unique                25146        NaN  158218       2        NaN     178686
# top     2015-05-01 00:00:00        NaN   Alone   movie        NaN  tt2299475
# freq                    173        NaN      84  178665        NaN          1
# first   1894-09-24 00:00:00        NaN     NaN     NaN        NaN        NaN
# last    2023-10-10 00:00:00        NaN     NaN     NaN        NaN        NaN
# mean                    NaN      36.05     NaN     NaN   1,992.56        NaN
# std                     NaN      45.52     NaN     NaN      33.03        NaN
# min                     NaN       0.00     NaN     NaN       0.00        NaN
# 25%                     NaN       0.00     NaN     NaN   1,989.00        NaN
# 50%                     NaN      12.00     NaN     NaN   2,007.00        NaN
# 75%                     NaN      75.00     NaN     NaN   2,013.00        NaN
# max                     NaN     964.00     NaN     NaN   2,023.00        NaN
#
#         imdbRating    imdbVotes
# count    62,073.00   178,686.00
# unique         NaN          NaN
# top            NaN          NaN
# freq           NaN          NaN
# first          NaN          NaN
# last           NaN          NaN
# mean          6.42     2,674.46
# std           1.36    28,777.22
# min           1.00         0.00
# 25%           5.60         0.00
# 50%           6.50         0.00
# 75%           7.30        13.00
# max          10.00 1,929,977.00

# %%
# Top 50 movies by imdbRating, also imdbVotes greater than 10000
voted_movies = movies[movies['imdbVotes']>10000]
voted_movies[['imdbID','Title','Country','imdbRating','imdbVotes']]\
    .sort_values(by=['imdbRating'], ascending=False)\
    .head(50)\
    .style\
    .background_gradient(subset='imdbRating', cmap='BuGn')\
    .hide_index()
# Out:
# <style  type="text/css" >
# #T_2b140_row0_col3{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_2b140_row1_col3{
#             background-color:  #0b7734;
#             color:  #f1f1f1;
#         }#T_2b140_row2_col3{
#             background-color:  #228a44;
#             color:  #000000;
#         }#T_2b140_row3_col3,#T_2b140_row4_col3,#T_2b140_row5_col3{
#             background-color:  #65c2a3;
#             color:  #000000;
#         }#T_2b140_row6_col3,#T_2b140_row7_col3,#T_2b140_row8_col3,#T_2b140_row9_col3{
#             background-color:  #88d1bd;
#             color:  #000000;
#         }#T_2b140_row10_col3,#T_2b140_row11_col3,#T_2b140_row12_col3,#T_2b140_row13_col3{
#             background-color:  #aadfd3;
#             color:  #000000;
#         }#T_2b140_row14_col3,#T_2b140_row15_col3,#T_2b140_row16_col3,#T_2b140_row17_col3,#T_2b140_row18_col3,#T_2b140_row19_col3{
#             background-color:  #cdece6;
#             color:  #000000;
#         }#T_2b140_row20_col3,#T_2b140_row21_col3,#T_2b140_row22_col3,#T_2b140_row23_col3,#T_2b140_row24_col3,#T_2b140_row25_col3,#T_2b140_row26_col3,#T_2b140_row27_col3,#T_2b140_row28_col3,#T_2b140_row29_col3,#T_2b140_row30_col3,#T_2b140_row31_col3,#T_2b140_row32_col3{
#             background-color:  #ddf2f3;
#             color:  #000000;
#         }#T_2b140_row33_col3,#T_2b140_row34_col3,#T_2b140_row35_col3,#T_2b140_row36_col3,#T_2b140_row37_col3,#T_2b140_row38_col3,#T_2b140_row39_col3,#T_2b140_row40_col3,#T_2b140_row41_col3,#T_2b140_row42_col3,#T_2b140_row43_col3,#T_2b140_row44_col3,#T_2b140_row45_col3{
#             background-color:  #ebf7fa;
#             color:  #000000;
#         }#T_2b140_row46_col3,#T_2b140_row47_col3,#T_2b140_row48_col3,#T_2b140_row49_col3{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }</style><table id="T_2b140_" ><thead>    <tr>        <th class="col_heading level0 col0" >imdbID</th>        <th class="col_heading level0 col1" >Title</th>        <th class="col_heading level0 col2" >Country</th>        <th class="col_heading level0 col3" >imdbRating</th>        <th class="col_heading level0 col4" >imdbVotes</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_2b140_row0_col0" class="data row0 col0" >tt5813916</td>
#                         <td id="T_2b140_row0_col1" class="data row0 col1" >The Mountain II</td>
#                         <td id="T_2b140_row0_col2" class="data row0 col2" >Turkey</td>
#                         <td id="T_2b140_row0_col3" class="data row0 col3" >9.600000</td>
#                         <td id="T_2b140_row0_col4" class="data row0 col4" >94751</td>
#             </tr>
#             <tr>
#                                 <td id="T_2b140_row1_col0" class="data row1 col0" >tt0252487</td>
#                         <td id="T_2b140_row1_col1" class="data row1 col1" >The Chaos Class</td>
#                         <td id="T_2b140_row1_col2" class="data row1 col2" >Turkey</td>
#                         <td id="T_2b140_row1_col3" class="data row1 col3" >9.400000</td>
#                         <td id="T_2b140_row1_col4" class="data row1 col4" >30462</td>
#             </tr>
#             <tr>
#                                 <td id="T_2b140_row2_col0" class="data row2 col0" >tt0111161</td>
#                         <td id="T_2b140_row2_col1" class="data row2 col1" >The Shawshank Redemption</td>
#                         <td id="T_2b140_row2_col2" class="data row2 col2" >USA</td>
#                         <td id="T_2b140_row2_col3" class="data row2 col3" >9.300000</td>
#                         <td id="T_2b140_row2_col4" class="data row2 col4" >1929977</td>
#             </tr>
#             <tr>
#                                 <td id="T_2b140_row3_col0" class="data row3 col0" >tt6316138</td>
#                         <td id="T_2b140_row3_col1" class="data row3 col1" >Ayla: The Daughter of War</td>
#                         <td id="T_2b140_row3_col2" class="data row3 col2" >Turkey</td>
#                         <td id="T_2b140_row3_col3" class="data row3 col3" >9.000000</td>
#                         <td id="T_2b140_row3_col4" class="data row3 col4" >18613</td>
#             </tr>
#             <tr>
#                                 <td id="T_2b140_row4_col0" class="data row4 col0" >tt0468569</td>
#                         <td id="T_2b140_row4_col1" class="data row4 col1" >The Dark Knight</td>
#                         <td id="T_2b140_row4_col2" class="data row4 col2" >USA, UK</td>
#                         <td id="T_2b140_row4_col3" class="data row4 col3" >9.000000</td>
#                         <td id="T_2b140_row4_col4" class="data row4 col4" >1896843</td>
#             </tr>
#             <tr>
#                                 <td id="T_2b140_row5_col0" class="data row5 col0" >tt0253779</td>
#                         <td id="T_2b140_row5_col1" class="data row5 col1" >The Foster Brothers</td>
#                         <td id="T_2b140_row5_col2" class="data row5 col2" >Turkey</td>
#                         <td id="T_2b140_row5_col3" class="data row5 col3" >9.000000</td>
#                         <td id="T_2b140_row5_col4" class="data row5 col4" >15530</td>
#             </tr>
#             <tr>
#                                 <td id="T_2b140_row6_col0" class="data row6 col0" >tt0167260</td>
#                         <td id="T_2b140_row6_col1" class="data row6 col1" >The Lord of the Rings: The Return of the King</td>
#                         <td id="T_2b140_row6_col2" class="data row6 col2" >USA, New Zealand</td>
#                         <td id="T_2b140_row6_col3" class="data row6 col3" >8.900000</td>
#                         <td id="T_2b140_row6_col4" class="data row6 col4" >1367235</td>
#             </tr>
#             <tr>
#                                 <td id="T_2b140_row7_col0" class="data row7 col0" >tt0110912</td>
#                         <td id="T_2b140_row7_col1" class="data row7 col1" >Pulp Fiction</td>
#                         <td id="T_2b140_row7_col2" class="data row7 col2" >USA</td>
#                         <td id="T_2b140_row7_col3" class="data row7 col3" >8.900000</td>
#                         <td id="T_2b140_row7_col4" class="data row7 col4" >1501400</td>
#             </tr>
#             <tr>
#                                 <td id="T_2b140_row8_col0" class="data row8 col0" >tt0108052</td>
#                         <td id="T_2b140_row8_col1" class="data row8 col1" >Schindler's List</td>
#                         <td id="T_2b140_row8_col2" class="data row8 col2" >USA</td>
#                         <td id="T_2b140_row8_col3" class="data row8 col3" >8.900000</td>
#                         <td id="T_2b140_row8_col4" class="data row8 col4" >989411</td>
#             </tr>
#             <tr>
#                                 <td id="T_2b140_row9_col0" class="data row9 col0" >tt0252490</td>
#                         <td id="T_2b140_row9_col1" class="data row9 col1" >The Chaos Class Is Waking Up</td>
#                         <td id="T_2b140_row9_col2" class="data row9 col2" >Turkey</td>
#                         <td id="T_2b140_row9_col3" class="data row9 col3" >8.900000</td>
#                         <td id="T_2b140_row9_col4" class="data row9 col4" >14139</td>
#             </tr>
#             <tr>
#                                 <td id="T_2b140_row10_col0" class="data row10 col0" >tt0109830</td>
#                         <td id="T_2b140_row10_col1" class="data row10 col1" >Forrest Gump</td>
#                         <td id="T_2b140_row10_col2" class="data row10 col2" >USA</td>
#                         <td id="T_2b140_row10_col3" class="data row10 col3" >8.800000</td>
#                         <td id="T_2b140_row10_col4" class="data row10 col4" >1449570</td>
#             </tr>
#             <tr>
#                                 <td id="T_2b140_row11_col0" class="data row11 col0" >tt0137523</td>
#                         <td id="T_2b140_row11_col1" class="data row11 col1" >Fight Club</td>
#                         <td id="T_2b140_row11_col2" class="data row11 col2" >USA, Germany</td>
#                         <td id="T_2b140_row11_

# %%
# Most voted movies imdbRating plot
voted_movies.imdbRating.hist()
# Out:
# <AxesSubplot:>

# %%
# Plot Distribution of length of film in hours
plt.hist(voted_movies['Runtime'].fillna(0) / 60, bins=40);
plt.title('Distribution of length of film in hours');
plt.xlabel('Duration of Movie in Hours')
plt.ylabel('Number of Movies')
# Out:
# Text(0, 0.5, 'Number of Movies')

# %%
# Plot Movie Release count by Year
plt.figure(figsize=(20,12))
edgecolor=(0,0,0),
sns.countplot(voted_movies[voted_movies.Year>2000]['Year'].sort_values(), palette = "Dark2", edgecolor=(0,0,0))
plt.title("Movie Release count by Year")
plt.xlabel('Release Year')
plt.ylabel('Number of Movies Release')
plt.xticks(fontsize=12,rotation=90)
plt.show()

# %%
# Plot Movie Rating Count
plt.figure(figsize=(20,12))
edgecolor=(0,0,0),
sns.distplot(voted_movies[voted_movies.Year>2000]['imdbRating'], kde=False)
plt.title("Movie Rating Count")
plt.xlabel('IMDB Rating')
plt.ylabel('Count')
plt.xticks(fontsize=12,rotation=90)
plt.show()

# %%
# Plot of most voted movies in last 20 years, by production year
movie_count = (voted_movies[voted_movies.Year>2000][["Year", "imdbID"]]
             .groupby("Year")
             .count()
            )
(movie_count
 .rolling(5).mean().rename(columns={"imdbID":"count"})
 .plot(figsize=(15,5),
       title="Count of Rated Movies - by production year")
)
# Out:
# <AxesSubplot:title={'center':'Count of Rated Movies - by production year'}, xlabel='Year'>

# %%
# Genres info
genres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308565 entries, 0 to 308564
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  308565 non-null  int64
#  1   Genre       308565 non-null  object
#  2   imdbID      308565 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 7.1+ MB

# %%
# Drop unnecessary column
genres.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# Join genres to movies filtering movies after 2000
voted_movies_genres = pd.merge(voted_movies[voted_movies.Year>2000],genres,how='left', on=['imdbID','imdbID'])

# %%
# Overview of joined dataframe
voted_movies_genres.head(10)
# Out:
#                  Country          Director                   Language  \
# 0                    USA       Max Nichols                    English
# 1                    USA       Max Nichols                    English
# 2                    USA  Charles Ferguson                    English
# 3                    USA  Charles Ferguson                    English
# 4                    USA        Mel Gibson     Aramaic, Latin, Hebrew
# 5                    USA       Ben Affleck                    English
# 6                    USA       Ben Affleck                    English
# 7                    USA       Ben Affleck                    English
# 8  Spain, Mexico, France     Icíar Bollaín  Spanish, Quechua, English
# 9  Spain, Mexico, France     Icíar Bollaín  Spanish, Quechua, English
#
#                Production    Rated   Released  Runtime  \
# 0     E One Entertainment        R 2014-09-26       86
# 1     E One Entertainment        R 2014-09-26       86
# 2  Sony Pictures Classics    PG-13 2010-11-12      105
# 3  Sony Pictures Classics    PG-13 2010-11-12      105
# 4    Newmarket Film Group        R 2004-02-25      127
# 5                 Miramax        R 2007-10-19      114
# 6                 Miramax        R 2007-10-19      114
# 7                 Miramax        R 2007-10-19      114
# 8         Vitagraph Films  UNRATED 2011-01-05      103
# 9         Vitagraph Films  UNRATED 2011-01-05      103
#
#                        Title   Type  Year     imdbID  imdbRating  imdbVotes  \
# 0            Two Night Stand  movie  2014  tt2140619        6.40      55239
# 1            Two Night Stand  movie  2014  tt2140619        6.40      55239
# 2                 Inside Job  movie  2010  tt1645089        8.30      62391
# 3                 Inside Job  movie  2010  tt1645089        8.30      62391
# 4  The Passion of the Christ  movie  2004  tt0335345        7.20     192148
# 5             Gone Baby Gone  movie  2007  tt0452623        7.70     219487
# 6             Gone Baby Gone  movie  2007  tt0452623        7.70     219487
# 7             Gone Baby Gone  movie  2007  tt0452623        7.70     219487
# 8              Even the Rain  movie  2010  tt1422032        7.50      10894
# 9              Even the Rain  movie  2010  tt1422032        7.50      10894
#
#          Genre
# 0       Comedy
# 1      Romance
# 2  Documentary
# 3        Crime
# 4        Drama
# 5        Crime
# 6        Drama
# 7      Mystery
# 8        Drama
# 9      History

# %%
# List all genres
voted_movies_genres.Genre = voted_movies_genres.Genre.astype('category')
voted_movies_genres.Genre.cat.categories
# Out:
# Index([' Action', ' Adventure', ' Biography', ' Comedy', ' Crime', ' Drama',
#        ' Family', ' Fantasy', ' History', ' Horror', ' Music', ' Musical',
#        ' Mystery', ' News', ' Romance', ' Sci-Fi', ' Short', ' Sport',
#        ' Thriller', ' War', ' Western', 'Action', 'Adventure', 'Animation',
#        'Biography', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Family',
#        'Fantasy', 'Horror', 'Music', 'Mystery', 'Romance', 'Sci-Fi', 'Short',
#        'Thriller', 'Western'],
#       dtype='object')

# %%
# Top 6 genres by movie count
voted_movies_genres['Genre'].value_counts().head(6)
# Out:
#  Drama       982
# Comedy       763
# Action       736
#  Romance     521
#  Thriller    497
# Drama        488
# Name: Genre, dtype: int64

# %%
# Clean whitespace from genre and count again
voted_movies_genres['Genre'] = voted_movies_genres['Genre'].str.strip()
top6_genre = voted_movies_genres['Genre'].value_counts().head(6)
top6_genre
# Out:
# Drama        1470
# Comedy       1165
# Action        794
# Adventure     639
# Crime         554
# Romance       524
# Name: Genre, dtype: int64

# %%
# Top Country by movie count in top 6 genres
top6_genre_keys = top6_genre.keys()
top6_genre_movies = voted_movies_genres.loc[voted_movies_genres['Genre'].isin(top6_genre_keys)]
top6_genre_movies['Country'].value_counts().head(6)
# Out:
# USA             2821
# UK, USA          167
# USA, Germany     153
# USA, UK          126
# USA, Canada      104
# UK                99
# Name: Country, dtype: int64

# %%
# Top 10 genres by IMDB Rating
m_genre_mean = voted_movies_genres.groupby(['Genre']).mean()
m_genre_mean.sort_values(by='imdbRating',ascending=False,inplace=True)

# %%
# Plot IMDB rating by genre
m_genre_mean[['imdbRating']].plot.barh(stacked=True, title = 'imdbRating by Genre',color='DarkBlue', figsize=(10, 9));

# %%
# Genres with >= 8 ratings
md_8 = voted_movies_genres[voted_movies_genres['imdbRating']>=8]
md_8 = (pd.DataFrame(voted_movies_genres.groupby('Genre').imdbID.nunique())).sort_values('imdbID', ascending=True )
md_8[['imdbID']].plot.barh(stacked=True, title = 'Genres with >= 8 ratings', figsize=(10, 9),color='DarkBlue');
